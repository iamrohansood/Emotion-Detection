# %% [markdown]
# # Import Necesssary Libraries

# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten
from keras.optimizers import Adam, RMSprop, SGD
from keras import regularizers
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
import datetime
import matplotlib.pyplot as plt
from keras.utils import plot_model
from pylab import rcParams
rcParams['figure.figsize'] = 5, 2.5
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Importing the Dataset

# %%
train_dir = '../input/fer2013/train/'
test_dir = '../input/fer2013/test/'

row, col = 48, 48
classes = 7

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df

train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')
print(train_count)
print(test_count)
# Out:
#        surprise  fear  angry  neutral   sad  disgust  happy
# train      3171  4097   3995     4965  4830      436   7215
#       surprise  fear  angry  neutral   sad  disgust  happy
# test       831  1024    958     1233  1247      111   1774

# %% [markdown]
# # Basic Plots for the Data

# %%
train_count.transpose().plot(kind='bar')
# Out:
# <Axes: >

# %%
test_count.transpose().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(14,22))
i = 1
for expression in os.listdir(train_dir):
    img = load_img((train_dir + expression +'/'+ os.listdir(train_dir + expression)[1]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# # Creating Training and Testing Sets

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.3,
                                   horizontal_flip=True)

training_set = train_datagen.flow_from_directory(train_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(test_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
training_set.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %% [markdown]
# # Define the Model

# %%
def get_model(input_size, classes=7):
     #Initialising the CNN
    model = tf.keras.models.Sequential()   

    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_size))
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2, 2))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(classes, activation='softmax'))

    #Compliling the model
    custom_optimizer = Adam(learning_rate = 0.0001, weight_decay = 1e-6)
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer=custom_optimizer)
    return model

# %% [markdown]
# # Model Summary

# %%
fernet = get_model((row,col,1), classes)
fernet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization (Batch  (None, 48, 48, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 256)       295168
#
#  batch_normalization_1 (Bat  (None, 22, 22, 256)       1024
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 11, 11, 256)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 256)       0
#
#  flatten (Flatten)           (None, 30976)             0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense (Dense)               (None, 1024)              31720448
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 32116743 (122.52 MB)
# Trainable params: 32116103 (122.51 MB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________

# %% [markdown]
# # Model Visualization

# %%
from keras.utils import plot_model
plot_model(fernet, to_file='model.png')

# %% [markdown]
# # Callbacks Function

# %%
chk_path = 'ferNet.h5'
log_dir = "checkpoint/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             moniter='val_loss')

earlystop = EarlyStopping(monitor='val_loss', 
                          min_delta=0, 
                          patience=3, 
                          verbose=1, 
                          restore_best_weights=True)
                        
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
csv_logger = CSVLogger('training.log')

callbacks = [checkpoint, reduce_lr, csv_logger]

# %% [markdown]
# # Training Model

# %%
steps_per_epoch = training_set.n // training_set.batch_size
validation_steps = test_set.n // test_set.batch_size

hist = fernet.fit(x=training_set,
                 validation_data=test_set,
                 epochs=60,
                 callbacks=callbacks,
                 steps_per_epoch=steps_per_epoch,
                 validation_steps=validation_steps)
# Out:
# Epoch 1/60
# 2023-11-29 02:51:31.868219: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 448/448 [==============================] - ETA: 0s - loss: 4.3701 - accuracy: 0.2829
# Epoch 1: val_loss improved from inf to 11.12883, saving model to ferNet.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 448/448 [==============================] - 156s 325ms/step - loss: 4.3701 - accuracy: 0.2829 - val_loss: 11.1288 - val_accuracy: 0.1264 - lr: 1.0000e-04
# Epoch 2/60
# 448/448 [==============================] - ETA: 0s - loss: 3.6400 - accuracy: 0.3329
# Epoch 2: val_loss improved from 11.12883 to 3.35107, saving model to ferNet.h5
# 448/448 [==============================] - 41s 92ms/step - loss: 3.6400 - accuracy: 0.3329 - val_loss: 3.3511 - val_accuracy: 0.3990 - lr: 1.0000e-04
# Epoch 3/60
# 448/448 [==============================] - ETA: 0s - loss: 3.1318 - accuracy: 0.3568
# Epoch 3: val_loss improved from 3.35107 to 2.78984, saving model to ferNet.h5
# 448/448 [==============================] - 42s 93ms/step - loss: 3.1318 - accuracy: 0.3568 - val_loss: 2.7898 - val_accuracy: 0.4187 - lr: 1.0000e-04
# Epoch 4/60
# 448/448 [==============================] - ETA: 0s - loss: 2.7001 - accuracy: 0.3870
# Epoch 4: val_loss improved from 2.78984 to 2.45108, saving model to ferNet.h5
# 448/448 [==============================] - 42s 93ms/step - loss: 2.7001 - accuracy: 0.3870 - val_loss: 2.4511 - val_accuracy: 0.4295 - lr: 1.0000e-04
# Epoch 5/60
# 448/448 [==============================] - ETA: 0s - loss: 2.3667 - accuracy: 0.4094
# Epoch 5: val_loss improved from 2.45108 to 2.14216, saving model to ferNet.h5
# 448/448 [==============================] - 41s 90ms/step - loss: 2.3667 - accuracy: 0.4094 - val_loss: 2.1422 - val_accuracy: 0.4541 - lr: 1.0000e-04
# Epoch 6/60
# 448/448 [==============================] - ETA: 0s - loss: 2.1116 - accuracy: 0.4273
# Epoch 6: val_loss improved from 2.14216 to 1.92083, saving model to ferNet.h5
# 448/448 [==============================] - 41s 91ms/step - loss: 2.1116 - accuracy: 0.4273 - val_loss: 1.9208 - val_accuracy: 0.4858 - lr: 1.0000e-04
# Epoch 7/60
# 448/448 [==============================] - ETA: 0s - loss: 1.9142 - accuracy: 0.4465
# Epoch 7: val_loss improved from 1.92083 to 1.70661, saving model to ferNet.h5
# 448/448 [==============================] - 42s 94ms/step - loss: 1.9142 - accuracy: 0.4465 - val_loss: 1.7066 - val_accuracy: 0.5046 - lr: 1.0000e-04
# Epoch 8/60
# 448/448 [==============================] - ETA: 0s - loss: 1.7632 - accuracy: 0.4610
# Epoch 8: val_loss improved from 1.70661 to 1.59146, saving model to ferNet.h5
# 448/448 [==============================] - 42s 94ms/step - loss: 1.7632 - accuracy: 0.4610 - val_loss: 1.5915 - val_accuracy: 0.5126 - lr: 1.0000e-04
# Epoch 9/60
# 448/448 [==============================] - ETA: 0s - loss: 1.6526 - accuracy: 0.4725
# Epoch 9: val_loss improved from 1.59146 to 1.48758, saving model to ferNet.h5
# 448/448 [==============================] - 41s 93ms/step - loss: 1.6526 - accuracy: 0.4725 - val_loss: 1.4876 - val_accuracy: 0.5254 - lr: 1.0000e-04
# Epoch 10/60
# 448/448 [==============================] - ETA: 0s - loss: 1.5607 - accuracy: 0.4877
# Epoch 10: val_loss improved from 1.48758 to 1.44472, saving model to ferNet.h5
# 448/448 [==============================] - 41s 92ms/step - loss: 1.5607 - accuracy: 0.4877 - val_loss: 1.4447 - val_accuracy: 0.5287 - lr: 1.0000e-04
# Epoch 11/60
# 448/448 [==============================] - ETA: 0s - loss: 1.4920 - accuracy: 0.5004
# Epoch 11: val_loss improved from 1.44472 to 1.39470, saving model to ferNet.h5
# 448/448 [==============================] - 41s 91ms/step - loss: 1.4920 - accuracy: 0.5004 - val_loss: 1.3947 - val_accuracy: 0.5297 - lr: 1.0000e-04
# Epoch 12/60
# 448/448 [==============================] - ETA: 0s - loss: 1.4370 - accuracy: 0.5168
# Epoch 12: val_loss improved from 1.39470 to 1.34027, saving model to ferNet.h5
# 448/448 [==============================] - 42s 94ms/step - loss: 1.4370 - accuracy: 0.5168 - val_loss: 1.3403 - val_accuracy: 0.5388 - lr: 1.0000e-04
# Epoch 13/60
# 448/448 [==============================] - ETA: 0s - loss: 1.3839 - accuracy: 0.5251
# Epoch 13: val_loss improved from 1.34027 to 1.28699, saving model to ferNet.h5
# 448/448 [==============================] - 40s 90ms/step - loss: 1.3839 - accuracy: 0.5251 - val_loss: 1.2870 - val_accuracy: 0.5576 - lr: 1.0000e-04
# Epoch 14/60
# 448/448 [==============================] - ETA: 0s - loss: 1.3420 - accuracy: 0.5380
# Epoch 14: val_loss improved from 1.28699 to 1.24268, saving model to ferNet.h5
# 448/448 [==============================] - 41s 91ms/step - loss: 1.3420 - accuracy: 0.5380 - val_loss: 1.2427 - val_accuracy: 0.5755 - lr: 1.0000e-04
# Epoch 15/60
# 448/448 [==============================] - ETA: 0s - loss: 1.3039 - accuracy: 0.5560
# Epoch 15: val_loss did not improve from 1.24268
# 448/448 [==============================] - 42s 94ms/step - loss: 1.3039 - accuracy: 0.5560 - val_loss: 1.2601 - val_accuracy: 0.5661 - lr: 1.0000e-04
# Epoch 16/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2641 - accuracy: 0.5632
# Epoch 16: val_loss improved from 1.24268 to 1.21067, saving model to ferNet.h5
# 448/448 [==============================] - 43s 95ms/step - loss: 1.2641 - accuracy: 0.5632 - val_loss: 1.2107 - val_accuracy: 0.5864 - lr: 1.0000e-04
# Epoch 17/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2407 - accuracy: 0.5709
# Epoch 17: val_loss did not improve from 1.21067
# 448/448 [==============================] - 42s 93ms/step - loss: 1.2407 - accuracy: 0.5709 - val_loss: 1.2201 - val_accuracy: 0.5818 - lr: 1.0000e-04
# Epoch 18/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2155 - accuracy: 0.5755
# Epoch 18: val_loss improved from 1.21067 to 1.18820, saving model to ferNet.h5
# 448/448 [==============================] - 43s 95ms/step - loss: 1.2155 - accuracy: 0.5755 - val_loss: 1.1882 - val_accuracy: 0.5854 - lr: 1.0000e-04
# Epoch 19/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1943 - accuracy: 0.5879
# Epoch 19: val_loss improved from 1.18820 to 1.17337, saving model to ferNet.h5
# 448/448 [==============================] - 43s 95ms/step - loss: 1.1943 - accuracy: 0.5879 - val_loss: 1.1734 - val_accuracy: 0.5865 - lr: 1.0000e-04
# Epoch 20/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1634 - accuracy: 0.5976
# Epoch 20: val_loss improved from 1.17337 to 1.16575, saving model to ferNet.h5
# 448/448 [==============================] - 42s 94ms/step - loss: 1.1634 - accuracy: 0.5976 - val_loss: 1.1657 - val_accuracy: 0.6002 - lr: 1.0000e-04
# Epoch 21/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1321 - accuracy: 0.6083
# Epoch 21: val_loss improved from 1.16575 to 1.16120, saving model to ferNet.h5
# 448/448 [==============================] - 44s 99ms/step - loss: 1.1321 - accuracy: 0.6083 - val_loss: 1.1612 - val_accuracy: 0.6024 - lr: 1.0000e-04
# Epoch 22/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1083 - accuracy: 0.6179
# Epoch 22: val_loss did not improve from 1.16120
# 448/448 [==============================] - 43s 96ms/step - loss: 1.1083 - accuracy: 0.6179 - val_loss: 1.1785 - val_accuracy: 0.5946 - lr: 1.0000e-04
# Epoch 23/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0886 - accuracy: 0.6268
# Epoch 23: val_loss improved from 1.16120 to 1.12785, saving model to ferNet.h5
# 448/448 [==============================] - 42s 95ms/step - loss: 1.0886 - accuracy: 0.6268 - val_loss: 1.1279 - val_accuracy: 0.6097 - lr: 1.0000e-04
# Epoch 24/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0641 - accuracy: 0.6351
# Epoch 24: val_loss did not improve from 1.12785
# 448/448 [==============================] - 40s 90ms/step - loss: 1.0641 - accuracy: 0.6351 - val_loss: 1.1489 - val_accuracy: 0.6104 - lr: 1.0000e-04
# Epoch 25/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0514 - accuracy: 0.6401
# Epoch 25: val_loss improved from 1.12785 to 1.10755, saving model to ferNet.h5
# 448/448 [==============================] - 43s 95ms/step - loss: 1.0514 - accuracy: 0.6401 - val_loss: 1.1075 - val_accuracy: 0.6204 - lr: 1.0000e-04
# Epoch 26/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0281 - accuracy: 0.6518
# Epoch 26: val_loss did not improve from 1.10755
# 448/448 [==============================] - 41s 92ms/step - loss: 1.0281 - accuracy: 0.6518 - val_loss: 1.1416 - val_accuracy: 0.6175 - lr: 1.0000e-04
# Epoch 27/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0084 - accuracy: 0.6553
# Epoch 27: val_loss did not improve from 1.10755
# 448/448 [==============================] - 45s 101ms/step - loss: 1.0084 - accuracy: 0.6553 - val_loss: 1.1715 - val_accuracy: 0.6123 - lr: 1.0000e-04
# Epoch 28/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9987 - accuracy: 0.6608
# Epoch 28: val_loss did not improve from 1.10755
# 448/448 [==============================] - 42s 93ms/step - loss: 0.9987 - accuracy: 0.6608 - val_loss: 1.1691 - val_accuracy: 0.6249 - lr: 1.0000e-04
# Epoch 29/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9743 - accuracy: 0.6694
# Epoch 29: val_loss improved from 1.10755 to 1.10213, saving model to ferNet.h5
# 448/448 [==============================] - 42s 93ms/step - loss: 0.9743 - accuracy: 0.6694 - val_loss: 1.1021 - val_accuracy: 0.6289 - lr: 1.0000e-04
# Epoch 30/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9561 - accuracy: 0.6772
# Epoch 30: val_loss did not improve from 1.10213
# 448/448 [==============================] - 41s 92ms/step - loss: 0.9561 - accuracy: 0.6772 - val_loss: 1.1454 - val_accuracy: 0.6145 - lr: 1.0000e-04
# Epoch 31/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9333 - accuracy: 0.6875
# Epoch 31: val_loss did not improve from 1.10213
# 448/448 [==============================] - 41s 91ms/step - loss: 0.9333 - accuracy: 0.6875 - val_loss: 1.1311 - val_accuracy: 0.6198 - lr: 1.0000e-04
# Epoch 32/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9206 - accuracy: 0.6894
# Epoch 32: val_loss did not improve from 1.10213
# 448/448 [==============================] - 42s 94ms/step - loss: 0.9206 - accuracy: 0.6894 - val_loss: 1.1475 - val_accuracy: 0.6272 - lr: 1.0000e-04
# Epoch 33/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9027 - accuracy: 0.6970
# Epoch 33: val_loss did not improve from 1.10213
# 448/448 [==============================] - 42s 93ms/step - loss: 0.9027 - accuracy: 0.6970 - val_loss: 1.1518 - val_accuracy: 0.6270 - lr: 1.0000e-04
# Epoch 34/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8944 - accuracy: 0.7003
# Epoch 34: val_loss did not improve from 1.10213
# 448/448 [==============================] - 41s 91ms/step - loss: 0.8944 - accuracy: 0.7003 - val_loss: 1.1136 - val_accuracy: 0.6306 - lr: 1.0000e-04
# Epoch 35/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8748 - accuracy: 0.7078
# Epoch 35: val_loss did not improve from 1.10213
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 448/448 [==============================] - 42s 93ms/step - loss: 0.8748 - accuracy: 0.7078 - val_loss: 1.1152 - val_accuracy: 0.6346 - lr: 1.0000e-04
# Epoch 36/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8179 - accuracy: 0.7273
# Epoch 36: val_loss improved from 1.10213 to 1.09362, saving model to ferNet.h5
# 448/448 [==============================] - 44s 98ms/step - loss: 0.8179 - accuracy: 0.7273 - val_loss: 1.0936 - val_accuracy: 0.6477 - lr: 2.0000e-05
# Epoch 37/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7918 - accuracy: 0.7441
# Epoch 37: val_loss improved from 1.09362 to 1.08383, saving model to ferNet.h5
# 448/448 [==============================] - 42s 94ms/step - loss: 0.7918 - accuracy: 0.7441 - val_loss: 1.0838 - val_accuracy: 0.6454 - lr: 2.0000e-05
# Epoch 38/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7781 - accuracy: 0.7447
# Epoch 38: val_loss did not improve from 1.08383
# 448/448 [==============================] - 42s 94ms/step - loss: 0.7781 - accuracy: 0.7447 - val_loss: 1.0898 - val_accuracy: 0.6505 - lr: 2.0000e-05
# Epoch 39/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7636 - accuracy: 0.7505
# Epoch 39: val_loss did not improve from 1.08383
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7636 - accuracy: 0.7505 - val_loss: 1.0983 - val_accuracy: 0.6469 - lr: 2.0000e-05
# Epoch 40/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7468 - accuracy: 0.7566
# Epoch 40: val_loss did not improve from 1.08383
# 448/448 [==============================] - 40s 90ms/step - loss: 0.7468 - accuracy: 0.7566 - val_loss: 1.0869 - val_accuracy: 0.6500 - lr: 2.0000e-05
# Epoch 41/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7413 - accuracy: 0.7590
# Epoch 41: val_loss did not improve from 1.08383
# 448/448 [==============================] - 41s 92ms/step - loss: 0.7413 - accuracy: 0.7590 - val_loss: 1.0908 - val_accuracy: 0.6530 - lr: 2.0000e-05
# Epoch 42/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7365 - accuracy: 0.7601
# Epoch 42: val_loss improved from 1.08383 to 1.08373, saving model to ferNet.h5
# 448/448 [==============================] - 42s 93ms/step - loss: 0.7365 - accuracy: 0.7601 - val_loss: 1.0837 - val_accuracy: 0.6525 - lr: 2.0000e-05
# Epoch 43/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7275 - accuracy: 0.7623
# Epoch 43: val_loss did not improve from 1.08373
# 448/448 [==============================] - 41s 90ms/step - loss: 0.7275 - accuracy: 0.7623 - val_loss: 1.0946 - val_accuracy: 0.6540 - lr: 2.0000e-05
# Epoch 44/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7238 - accuracy: 0.7625
# Epoch 44: val_loss did not improve from 1.08373
# 448/448 [==============================] - 44s 99ms/step - loss: 0.7238 - accuracy: 0.7625 - val_loss: 1.0939 - val_accuracy: 0.6533 - lr: 2.0000e-05
# Epoch 45/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7144 - accuracy: 0.7633
# Epoch 45: val_loss did not improve from 1.08373
# 448/448 [==============================] - 48s 106ms/step - loss: 0.7144 - accuracy: 0.7633 - val_loss: 1.0987 - val_accuracy: 0.6498 - lr: 2.0000e-05
# Epoch 46/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7100 - accuracy: 0.7678
# Epoch 46: val_loss did not improve from 1.08373
# 448/448 [==============================] - 40s 89ms/step - loss: 0.7100 - accuracy: 0.7678 - val_loss: 1.1074 - val_accuracy: 0.6539 - lr: 2.0000e-05
# Epoch 47/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7066 - accuracy: 0.7690
# Epoch 47: val_loss did not improve from 1.08373
# 448/448 [==============================] - 40s 89ms/step - loss: 0.7066 - accuracy: 0.7690 - val_loss: 1.1120 - val_accuracy: 0.6508 - lr: 2.0000e-05
# Epoch 48/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7002 - accuracy: 0.7708
# Epoch 48: val_loss did not improve from 1.08373
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 448/448 [==============================] - 41s 91ms/step - loss: 0.7002 - accuracy: 0.7708 - val_loss: 1.1053 - val_accuracy: 0.6572 - lr: 2.0000e-05
# Epoch 49/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6805 - accuracy: 0.7797
# Epoch 49: val_loss did not improve from 1.08373
# 448/448 [==============================] - 42s 95ms/step - loss: 0.6805 - accuracy: 0.7797 - val_loss: 1.1013 - val_accuracy: 0.6536 - lr: 4.0000e-06
# Epoch 50/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6805 - accuracy: 0.7810
# Epoch 50: val_loss did not improve from 1.08373
# 448/448 [==============================] - 40s 89ms/step - loss: 0.6805 - accuracy: 0.7810 - val_loss: 1.0889 - val_accuracy: 0.6546 - lr: 4.0000e-06
# Epoch 51/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6801 - accuracy: 0.7781
# Epoch 51: val_loss did not improve from 1.08373
# 448/448 [==============================] - 41s 91ms/step - loss: 0.6801 - accuracy: 0.7781 - val_loss: 1.0960 - val_accuracy: 0.6567 - lr: 4.0000e-06
# Epoch 52/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6744 - accuracy: 0.7810
# Epoch 52: val_loss did not improve from 1.08373
# 448/448 [==============================] - 40s 89ms/step - loss: 0.6744 - accuracy: 0.7810 - val_loss: 1.0937 - val_accuracy: 0.6569 - lr: 4.0000e-06
# Epoch 53/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6739 - accuracy: 0.7799
# Epoch 53: val_loss did not improve from 1.08373
# 448/448 [==============================] - 40s 90ms/step - loss: 0.6739 - accuracy: 0.7799 - val_loss: 1.0963 - val_accuracy: 0.6539 - lr: 4.0000e-06
# Epoch 54/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6753 - accuracy: 0.7819
# Epoch 54: val_loss did not improve from 1.08373
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 448/448 [==============================] - 42s 93ms/step - loss: 0.6753 - accuracy: 0.7819 - val_loss: 1.0894 - val_accuracy: 0.6551 - lr: 4.0000e-06
# Epoch 55/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6650 - accuracy: 0.7848
# Epoch 55: val_loss did not improve from 1.08373
# 448/448 [==============================] - 42s 93ms/step - loss: 0.6650 - accuracy: 0.7848 - val_loss: 1.1026 - val_accuracy: 0.6581 - lr: 8.0000e-07
# Epoch 56/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6649 - accuracy: 0.7857
# Epoch 56: val_loss did not improve from 1.08373
# 448/448 [==============================] - 42s 93ms/step - loss: 0.6649 - accuracy: 0.7857 - val_loss: 1.1000 - val_accuracy: 0.6579 - lr: 8.0000e-07
# Epoch 57/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6743 - accuracy: 0.7778
# Epoch 57: val_loss did not improve from 1.08373
# 448/448 [==============================] - 41s 92ms/step - loss: 0.6743 - accuracy: 0.7778 - val_loss: 1.0901 - val_accuracy: 0.6568 - lr: 8.0000e-07
# Epoch 58/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6696 - accuracy: 0.7838
# Epoch 58: val_loss did not improve from 1.08373
# 448/448 [==============================] - 41s 92ms/step - loss: 0.6696 - accuracy: 0.7838 - val_loss: 1.0961 - val_accuracy: 0.6575 - lr: 8.0000e-07
# Epoch 59/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6596 - accuracy: 0.7870
# Epoch 59: val_loss did not improve from 1.08373
# 448/448 [==============================] - 40s 90ms/step - loss: 0.6596 - accuracy: 0.7870 - val_loss: 1.0921 - val_accuracy: 0.6565 - lr: 8.0000e-07
# Epoch 60/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6663 - accuracy: 0.7828
# Epoch 60: val_loss did not improve from 1.08373
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 448/448 [==============================] - 40s 90ms/step - loss: 0.6663 - accuracy: 0.7828 - val_loss: 1.0924 - val_accuracy: 0.6550 - lr: 8.0000e-07

# %% [markdown]
# # Loss and Accuracy Plots

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,2)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
train_loss, train_accu = fernet.evaluate(training_set)
test_loss, test_accu = fernet.evaluate(test_set)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 449/449 [==============================] - 35s 79ms/step - loss: 0.4953 - accuracy: 0.8697
# 113/113 [==============================] - 6s 52ms/step - loss: 1.1044 - accuracy: 0.6544
# final train accuracy = 86.97 , validation accuracy = 65.44

# %%
fernet.save_weights('fernet_bestweight.h5')

# %% [markdown]
# # Confusion Matrix and Classification on Training Set

# %%
y_pred = fernet.predict(training_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

from sklearn.metrics import classification_report, confusion_matrix
cm_train = confusion_matrix(training_set.classes, y_pred)
print('Confusion Matrix')
print(cm_train)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(training_set.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_train, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# 449/449 [==============================] - 35s 79ms/step
# Confusion Matrix
# [[ 511   59  525 1041  756  678  425]
#  [  52   10   57   99   85   76   57]
#  [ 573   49  524 1028  758  699  466]
#  [ 982   94  925 1917 1285 1193  819]
#  [ 658   59  630 1266  964  844  544]
#  [ 651   61  633 1278  875  838  494]
#  [ 426   43  418  805  612  521  346]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.13      0.13      0.13      3995
#      disgust       0.03      0.02      0.02       436
#         fear       0.14      0.13      0.13      4097
#        happy       0.26      0.27      0.26      7215
#      neutral       0.18      0.19      0.19      4965
#          sad       0.17      0.17      0.17      4830
#     surprise       0.11      0.11      0.11      3171
#
#     accuracy                           0.18     28709
#    macro avg       0.15      0.15      0.15     28709
# weighted avg       0.18      0.18      0.18     28709

# %% [markdown]
# # Confusion Matrix and Classification on Test Set

# %%
y_pred = fernet.predict(test_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

#from sklearn.metrics import classification_report, confusion_matrix
cm_test = confusion_matrix(test_set.classes, y_pred)
print('Confusion Matrix')
print(cm_test)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(test_set.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_test, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# 113/113 [==============================] - 6s 54ms/step
# Confusion Matrix
# [[145   7 123 228 198 146 111]
#  [ 20   0  13  34  12  19  13]
#  [150  10 125 259 186 181 113]
#  [277  18 196 443 350 295 195]
#  [177   9 129 300 270 201 147]
#  [175  14 151 309 225 218 155]
#  [148   5  95 208 155 129  91]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.13      0.15      0.14       958
#      disgust       0.00      0.00      0.00       111
#         fear       0.15      0.12      0.13      1024
#        happy       0.25      0.25      0.25      1774
#      neutral       0.19      0.22      0.21      1233
#          sad       0.18      0.17      0.18      1247
#     surprise       0.11      0.11      0.11       831
#
#     accuracy                           0.18      7178
#    macro avg       0.15      0.15      0.15      7178
# weighted avg       0.18      0.18      0.18      7178
